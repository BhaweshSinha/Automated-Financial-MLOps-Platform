# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# # Split Strategy
# ---------------------------------------------------------------------------------------------------------------
# ## Content log:
# 1. Import Libraries
# 2. Load processed Data
# 3. Ensure sorted by time
# 4. Time-based split (80-20)
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # 02. Load processed Data

# %%
df = pd.read_csv("../../data/processed/final_data.csv")
print("Shape:", df.shape)
print(df.head())
# Out:
# Shape: (74071, 12)
#          Date     Close         High          Low         Open    Volume  \
# 0  2016-03-02 -0.659265    73.822983    70.673584    71.482606   7180521
# 1  2016-03-03 -0.671764    48.668520    47.655333    48.526315   7057560
# 2  2016-03-03 -0.649779    93.264182    91.019518    91.852769   6511139
# 3  2016-03-03  0.948079  3329.809598  3266.810732  3310.453469    742263
# 4  2016-03-03 -0.657417    78.402941    75.631422    76.704897  16866745
#
#          Ticker   Returns      Ma_7     Ma_30  Volatility        Lag_1
# 0       NTPC_NS -0.387072 -0.807720 -1.329370    2.073169   207.282257
# 1  POWERGRID_NS -0.343964 -0.904697 -1.328569    2.107327    73.274002
# 2      WIPRO_NS -0.166293 -0.902084 -1.365961    2.087583    48.224140
# 3     MARUTI_NS  4.614971 -0.902674 -1.213696    1.553612    92.286392
# 4       ONGC_NS -0.433788 -0.926392 -1.359611    1.554210  3294.794922

# %% [markdown]
# # 03. Ensure sorted by time

# %%
df = df.sort_values("Date")

# %% [markdown]
# # 04. Time-based split (80-20)

# %%
split_ratio = 0.8
split_index = int(len(df) * split_ratio)
train_df = df.iloc[:split_index]
test_df = df.iloc[split_index:]
print("\nTrain shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (59256, 12)
# Test shape: (14815, 12)

# %% [markdown]
# # The final **splitting and data saving** is performed in **root/src/train_test_splitter.py** and saved inside **root/data/splits**
