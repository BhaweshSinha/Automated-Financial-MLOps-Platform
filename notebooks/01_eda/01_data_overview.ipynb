# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# # Data Overview
# ---------------------------------------------------------------------------------------------------------------
# ## Content log:
# 01. Import Libraries
# 02. Load Data
# 03. Data Overview
# 04. Missing Values Analysis
# 05. Checking Duplicated Values
# 06. Basic Statistics
# 07. Unique Value Check
# 08. Key Observations
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 01. Import Libraries

# %%
import os
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# %% [markdown]
# # 02. Load Data

# %%
data_path = "../../data/raw_data"
datasets = {}
for file in os.listdir(data_path):
    if file.endswith(".csv"):
        df = pd.read_csv(os.path.join(data_path, file))
        df["Ticker"] = file.replace(".csv", "")
        datasets[file] = df
print(f"Total datasets loaded: {len(datasets)}")
# Out:
# Total datasets loaded: 30

# %% [markdown]
# # 03. Dataset Overview

# %%
for name, df in datasets.items():
    print("="*60)
    print(f"Dataset: {name}")
    print("="*60)    
    print("\nShape:")
    print(df.shape)
    print("\nColumns:")
    print(df.columns.tolist())
    print("\nData Types:")
    print(df.dtypes)
    print("\nFirst 5 Rows:")
    display(df.head())
# Out:
# ...
# Dataset: ADANIENT_NS.csv
# ...
#
# Shape:
# (2470, 7)
#
# Columns:
# ['Date', 'Close', 'High', 'Low', 'Open', 'Volume', 'Ticker']
#
# Data Types:
# Date       object
# Close     float64
# High      float64
# Low       float64
# Open      float64
# Volume      int64
# Ticker     object
# dtype: object
#
# First 5 Rows:
#        Date      Close       High        Low       Open    Volume       Ticker
# 0  3/2/2016  32.988026  33.833198  32.274916  32.750322   9313684  ADANIENT_NS
# 1  3/3/2016  33.014435  33.542664  32.406969  33.278549   7706783  ADANIENT_NS
# 2  3/4/2016  33.384197  34.150133  33.014439  33.278553   9013442  ADANIENT_NS
# 3  3/8/2016  33.833191  34.070894  32.882374  33.542662  11091171  ADANIENT_NS
# 4  3/9/2016  35.074535  35.312239  33.331372  33.542664   7364105  ADANIENT_NS
# ...
# Dataset: ADANIPORTS_NS.csv
# ...
#
# Shape:
# (2470, 7)
#
# Columns:
# ['Date', 'Close', 'High', 'Low', 'Open', 'Volume', 'Ticker']
#
# Data Types:
# Date       object
# Close     float64
# ...

# %% [markdown]
# # 04. Missing Values Analysis

# %%
for name, df in datasets.items():
    print("="*60)
    print(f"Missing Values: {name}")
    print("="*60)
    missing = df.isnull().sum()
    missing = missing[missing > 0]
    if len(missing) == 0:
        print("No missing values")
    else:
        print(missing)
# Out:
# ...
# Missing Values: ADANIENT_NS.csv
# ...
# No missing values
# ...
# Missing Values: ADANIPORTS_NS.csv
# ...
# No missing values
# ...
# Missing Values: ASIANPAINT_NS.csv
# ...
# No missing values
# ...
# Missing Values: AXISBANK_NS.csv
# ...
# No missing values
# ...
# Missing Values: BAJAJFINSV_NS.csv
# ...
# No missing values
# ...
# Missing Values: BAJFINANCE_NS.csv
# ...
# No missing values
# ...
# Missing Values: BHARTIARTL_NS.csv
# ...
# No missing values
# ...
# Missing Values: DRREDDY_NS.csv
# ...
# No missing values
# ...
# Missing Values: EICHERMOT_NS.csv
# ...
# No missing values
# ...
# Missing Values: HCLTECH_NS.csv
# ...
# No missing values
# ...
# Missing Values: HDFCBANK_NS.csv
# ...
# No missing values
# ...
# Missing Values: HINDUNILVR_NS.csv
# ...
# No missing values
# ...
# Missing Values: ICICIBANK_NS.csv
# ...
# No missing values
# ...
# Missing Values: INFY_NS.csv
# ...
# No missing values
# ...
# Missing Values: ITC_NS.csv
# ...
# No missing values
# ...
# Missing Values: KOTAKBANK_NS.csv
# ...
# No missing values
# ...
# Missing Values: LT_NS.csv
# ...
# No missing values
# ...
# Missing Values: MARUTI_NS.csv
# ...
# No missing values
# ...

# %% [markdown]
# # 05. Checking Duplicated Values

# %%
for name, df in datasets.items():
    duplicates = df.duplicated().sum()
    print(f"{name} -> Duplicate Rows: {duplicates}")
# Out:
# ADANIENT_NS.csv -> Duplicate Rows: 0
# ADANIPORTS_NS.csv -> Duplicate Rows: 0
# ASIANPAINT_NS.csv -> Duplicate Rows: 0
# AXISBANK_NS.csv -> Duplicate Rows: 0
# BAJAJFINSV_NS.csv -> Duplicate Rows: 0
# BAJFINANCE_NS.csv -> Duplicate Rows: 0
# BHARTIARTL_NS.csv -> Duplicate Rows: 0
# DRREDDY_NS.csv -> Duplicate Rows: 0
# EICHERMOT_NS.csv -> Duplicate Rows: 0
# HCLTECH_NS.csv -> Duplicate Rows: 0
# HDFCBANK_NS.csv -> Duplicate Rows: 0
# HINDUNILVR_NS.csv -> Duplicate Rows: 0
# ICICIBANK_NS.csv -> Duplicate Rows: 0
# INFY_NS.csv -> Duplicate Rows: 0
# ITC_NS.csv -> Duplicate Rows: 0
# KOTAKBANK_NS.csv -> Duplicate Rows: 0
# LT_NS.csv -> Duplicate Rows: 0
# MARUTI_NS.csv -> Duplicate Rows: 0
# NESTLEIND_NS.csv -> Duplicate Rows: 0
# NTPC_NS.csv -> Duplicate Rows: 0
# ONGC_NS.csv -> Duplicate Rows: 0
# POWERGRID_NS.csv -> Duplicate Rows: 0
# RELIANCE_NS.csv -> Duplicate Rows: 0
# SBIN_NS.csv -> Duplicate Rows: 0
# SUNPHARMA_NS.csv -> Duplicate Rows: 0
# TCS_NS.csv -> Duplicate Rows: 0
# ...

# %% [markdown]
# # 06. Basic Statistics

# %%
for name, df in datasets.items():
    print("="*60)
    print(f"Statistical Summary: {name}")
    print("="*60)
    
    display(df.describe())
# Out:
# ...
# Statistical Summary: ADANIENT_NS.csv
# ...
#              Close         High          Low         Open        Volume
# count  2470.000000  2470.000000  2470.000000  2470.000000  2.470000e+03
# mean   1269.420366  1291.934146  1248.342980  1271.869465  6.127435e+06
# std    1226.836184  1246.403139  1209.534061  1230.282957  9.182199e+06
# min      32.906822    33.413899    31.145383    31.919348  0.000000e+00
# 25%     122.666697   125.825326   117.965612   122.356241  1.670581e+06
# 50%     871.109039   891.035666   852.928221   868.889447  3.653136e+06
# 75%    2385.621582  2420.470085  2352.688464  2395.816255  6.948777e+06
# max    4159.593750  4184.260452  4060.829331  4169.281000  1.701502e+08
# ...
# Statistical Summary: ADANIPORTS_NS.csv
# ...
#              Close         High          Low         Open        Volume
# count  2470.000000  2470.000000  2470.000000  2470.000000  2.470000e+03
# mean    673.903555   683.957267   664.305025   674.995695  5.501982e+06
# ...

# %% [markdown]
# # 07. Unique Value Check

# %%
for name, df in datasets.items():
    print("="*60)
    print(f"Unique Values: {name}")
    print("="*60)
    for col in df.columns:
        print(f"{col}: {df[col].nunique()} unique values")
# Out:
# ...
# Unique Values: ADANIENT_NS.csv
# ...
# Date: 2470 unique values
# Close: 2366 unique values
# High: 2459 unique values
# Low: 2455 unique values
# Open: 2452 unique values
# Volume: 2468 unique values
# Ticker: 1 unique values
# ...
# Unique Values: ADANIPORTS_NS.csv
# ...
# Date: 2470 unique values
# Close: 2346 unique values
# High: 2457 unique values
# Low: 2459 unique values
# Open: 2439 unique values
# Volume: 2469 unique values
# Ticker: 1 unique values
# ...
# Unique Values: ASIANPAINT_NS.csv
# ...
# Date: 2470 unique values
# Close: 2432 unique values
# High: 2466 unique values
# Low: 2470 unique values
# Open: 2465 unique values
# Volume: 2468 unique values
# Ticker: 1 unique values
# ...
# Unique Values: AXISBANK_NS.csv
# ...
# Date: 2470 unique values
# Close: 2361 unique values
# High: 2462 unique values
# Low: 2465 unique values
# Open: 2452 unique values
# Volume: 2469 unique values
# Ticker: 1 unique values
# ...
# Unique Values: BAJAJFINSV_NS.csv
# ...
# Date: 2470 unique values
# Close: 2444 unique values
# ...

# %% [markdown]
# # 08. Key Observations
# 1. Overall there are **30 datasets observed** in the data directory that was obtained from the data ingestion pipeline (ref. to: **root/src/data_ingestion.py**).
# 2. Accoding to **Dataset Overview**
#    * All the datasets are having common number of rows and columns.
#    * All datasets with columns/attrutes are having right data-type into it (so there is no type-casting required)
# 3. According to **Missing Values Analysis** any of datasets are **not having any type of missing values** in it.
# 4. Accoding to: **Checking Duplicated Values** there are **no any duplicated values** recorded in any individual dataset it means all the **values are unique**.

# %% [markdown]
# For Advanced EDA report please refer to:
# **root_dir/observations/advanced_eda_report.md**
# [Advanced EDA report](../../observations/advanced_eda_report.md)
