# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# # Data Overview
# ---------------------------------------------------------------------------------------------------------------
# ## Content log:
# 1. Import Libraries
# 2. Loading Splitted Data
# 3. Checking shapes of Splitted data
# 4. Basic Descriptive Statistics
# 5. Checking Nulls in training data
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # 02. Loading Splitted Data

# %%
train = pd.read_csv("../../data/splits/train.csv")
test = pd.read_csv("../../data/splits/test.csv")

# %% [markdown]
# # 03. Checking shapes of Splitted data

# %%
print("Train Shape:", train.shape)
print("Test Shape:", test.shape)
# Out:
# Train Shape: (59256, 12)
# Test Shape: (14815, 12)

# %% [markdown]
# # 04. Basic Descriptive Statistics

# %%
train.describe()
# Out:
#               Close          High           Low          Open        Volume  \
# count  59256.000000  59256.000000  59256.000000  59256.000000  5.925600e+04
# mean      -0.118140   1171.584902   1144.601725   1158.727092  9.021959e+06
# std        0.802916   1626.987219   1592.573153   1610.782492  1.376093e+07
# min       -0.679406     33.413899     31.145383     31.919348  2.622900e+04
# 25%       -0.554963    286.302112    278.798188    282.535549  1.696940e+06
# 50%       -0.399909    600.895805    585.708892    593.359685  4.707288e+06
# 75%       -0.093254   1219.031945   1194.972137   1207.163232  1.132170e+07
# max        5.004591  11486.018780  11246.106220  11471.269430  4.429906e+08
#
#             Returns          Ma_7         Ma_30    Volatility         Lag_1
# count  59256.000000  59256.000000  59256.000000  59256.000000  59256.000000
# mean       0.014482     -0.267672     -0.373249      0.042066   1157.704237
# ...

# %% [markdown]
# # 05. Checking Nulls in training data

# %%
train.isnull().sum()
# Out:
# Date          0
# Close         0
# High          0
# Low           0
# Open          0
# Volume        0
# Ticker        0
# Returns       0
# Ma_7          0
# Ma_30         0
# Volatility    0
# Lag_1         0
# dtype: int64
