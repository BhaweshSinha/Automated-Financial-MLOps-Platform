# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# # Data Cleaning
# ---------------------------------------------------------------------------------------------------------------
# ## Content log:
# 1. Import Libraries
# 2. Load Data
# 3. Remove duplicates
# 4. Handle missing Values
# 5. Date-time Processing
# 6. Final Checks
# 7. Saving Cleaned Data
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 01. Import Lbraries

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 02. Load Data

# %%
df = pd.read_csv("../../data/combined_dataset/combined_data.csv")

# %%
print("Initial Shape:", df.shape)
print(df.head())
# Out:
# Initial Shape: (74100, 7)
#        Date      Close       High        Low       Open    Volume       Ticker
# 0  3/2/2016  32.988026  33.833198  32.274916  32.750322   9313684  ADANIENT_NS
# 1  3/3/2016  33.014435  33.542664  32.406969  33.278549   7706783  ADANIENT_NS
# 2  3/4/2016  33.384197  34.150133  33.014439  33.278553   9013442  ADANIENT_NS
# 3  3/8/2016  33.833191  34.070894  32.882374  33.542662  11091171  ADANIENT_NS
# 4  3/9/2016  35.074535  35.312239  33.331372  33.542664   7364105  ADANIENT_NS

# %% [markdown]
# # 03. Remove duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# # 04. Handle missing Values

# %%
df = df.fillna(method="ffill")

# %% [markdown]
# # 05. Date-time Processing

# %%
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values('date')

# %% [markdown]
# # 06. Final Checks

# %%
print("After Cleaning Shape:", df.shape)
print("Missing Values:\n", df.isnull().sum())
# Out:
# After Cleaning Shape: (74100, 7)
# Missing Values:
#  Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# Ticker    0
# dtype: int64

# %% [markdown]
# # 07. Saving Cleaned Data

# %%
df.to_csv("../../data/interim/cleaned_data.csv", index=False)
